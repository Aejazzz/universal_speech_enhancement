# %% [markdown]
# # Policy Training Notebook
# Run supervised routing training and monitor TensorBoard logs.

# %%
from policy_agent.train import train_supervised
train_supervised("configs/base.yaml")
